# %% [markdown]
# # Object Detection Demo
# Welcome to the object detection inference walkthrough!  This notebook will walk you step by step through the process of using a pre-trained model to detect objects in an image. Make sure to follow the [installation instructions](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/installation.md) before you start.

# %% [markdown]
# # Imports

# %%
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from distutils.version import StrictVersion
from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops

if StrictVersion(tf.__version__) < StrictVersion('1.9.0'):
  raise ImportError('Please upgrade your TensorFlow installation to v1.9.* or later!')

# %% [markdown]
# ## Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# %% [markdown]
# ## Object detection imports
# Here are the imports from the object detection module.

# %%
from utils import label_map_util

from utils import visualization_utils as vis_util

# %% [markdown]
# # Model preparation

# %% [markdown]
# ## Variables
#
# Any model exported using the `export_inference_graph.py` tool can be loaded here simply by changing `PATH_TO_FROZEN_GRAPH` to point to a new .pb file.
#
# By default we use an "SSD with Mobilenet" model here. See the [detection model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/detection_model_zoo.md) for a list of other models that can be run out-of-the-box with varying speeds and accuracies.

# %%
# What model to download.
# MODEL_NAME = 'ssd_mobilenet_v1_coco_2017_11_17'
# MODEL_FILE = MODEL_NAME + '.tar.gz'
# DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

# Path to frozen detection graph. This is the actual model that is used for the object detection.
# PATH_TO_FROZEN_GRAPH = MODEL_NAME + '/frozen_inference_graph.pb'

# # List of the strings that is used to add correct label for each box.
# PATH_TO_LABELS = os.path.join('data', 'mscoco_label_map.pbtxt')

# %%
PATH_TO_FROZEN_GRAPH ="/Users/zhou/Desktop/duckietown/duckietown_training/models/model2/frozen_inference_graph.pb"

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = "/Users/zhou/Desktop/duckietown/duckietown_training/data/duckie_label_map.pbtxt"

# %% [markdown]
# ## Download Model

# %%
# opener = urllib.request.URLopener()
# opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)
# tar_file = tarfile.open(MODEL_FILE)
# for file in tar_file.getmembers():
#   file_name = os.path.basename(file.name)
#   if 'frozen_inference_graph.pb' in file_name:
#     tar_file.extract(file, os.getcwd())

# %% [markdown]
# ## Load a (frozen) Tensorflow model into memory.

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.GraphDef()
  with tf.gfile.GFile(PATH_TO_FROZEN_GRAPH, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')

# %% [markdown]
# ## Loading label map
# Label maps map indices to category names, so that when our convolution network predicts `5`, we know that this corresponds to `airplane`.  Here we use internal utility functions, but anything that returns a dictionary mapping integers to appropriate string labels would be fine

# %%
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# %% [markdown]
# ## Helper code

# %%
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Detection

# %%
# For the sake of simplicity we will use only 2 images:
# image1.jpg
# image2.jpg
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
# PATH_TO_TEST_IMAGES_DIR = 'test_images'
# TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, 'image{}.jpg'.format(i)) for i in range(1, 3) ]

# Size, in inches, of the output images.
PATH_TO_TEST_IMAGES_DIR = "/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average"
IMAGE_SIZE = (12, 8)

# %%
TEST_IMAGE_PATHS = [os.path.join(PATH_TO_TEST_IMAGES_DIR, image_name) for image_name 
                    in os.listdir(PATH_TO_TEST_IMAGES_DIR)]

# %%
TEST_IMAGE_PATHS
# Out:
# ['/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Blue_BR_Duckbar_frame00541.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_yanberbot_1377.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_zgxbot_00216.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_zgxbot_00073.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_zgxbot_00029.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_cr_zgxbot_00049.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_yanberbot_0642.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Blue_BR_Duckbar_frame01307.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_BR_doort_frame00227.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_zgxbot_00111.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_zgxbot_00050.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_CR_doort_frame00838.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_yanberbot_0677.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_yanberbot_1767.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_yanberbot_2121.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_CR_doort_frame00177.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_BR_Duckbar_frame01203.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_CR_doort_frame01312.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_br_yanberbot_0257.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_yanberbot_0514.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_br_zgxbot_00063.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_yanberbot_0087.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_zgxbot_00065.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_zgxbot_00160.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_zgxbot_00174.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_zgxbot_00059.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_yanberbot_0911.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_yanberbot_0716.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_CR_Duckbar_frame01906.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_cr_zgxbot_00115.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_br_zgxbot_00025.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_CR_Duckbar_frame00359.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/D_BR_Duckbar_frame00510.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_BR_doort_frame00192.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_br_zgxbot_00018.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_BR_doort_frame00844.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/M_BR_Duckbar_frame01415.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_yanberbot_0608.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_BR_Duckbar_frame00450.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/M_CR_Duckbar_frame00003.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_zgxbot_00149.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_zgxbot_00175.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_yanberbot_0478.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_CR_doort_frame01312.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_br_yanberbot_1799.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_yanberbot_2868.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_zgxbot_00110.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_yanberbot_1612.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Blue_BR_Duckbar_frame00030.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_yanberbot_0642.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_zgxbot_00000.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_zgxbot_00072.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/M_CR_Duckbar_frame00188.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_yanberbot_1438.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_br_yanberbot_3158.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_BR_Duckbar_frame00268.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_yanberbot_2254.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_yanberbot_0649.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_CR_Duckbar_frame02388.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_yanberbot_0959.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_zgxbot_00004.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_BR_doort_frame00199.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_yanberbot_1807.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Red_BR_Duckbar_frame01265.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_zgxbot_00038.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_yanberbot_1448.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_zgxbot_00058.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_CR_Duckbar_frame00951.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_BR_doort_frame01608.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_zgxbot_00112.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_zgxbot_00053.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_yanberbot_0488.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_br_yanberbot_1349.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_yanberbot_2251.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_yanberbot_1925.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_zgxbot_00188.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_br_zgxbot_00060.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_br_zgxbot_00048.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_BR_doort_frame01973.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_CR_Duckbar_frame00616.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_yanberbot_0462.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_yanberbot_1423.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_yanberbot_1345.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_CR_Duckbar_frame01093.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Green_BR_Duckbar_frame01294.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_br_zgxbot_00026.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_cr_zgxbot_00116.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/B_CR_Duckbar_frame00428.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_zgxbot_00164.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/M_CR_Duckbar_frame00798.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Green_BR_Duckbar_frame01243.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_yanberbot_0687.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/M_BR_Duckbar_frame00734.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_cr_yanberbot_1892.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_br_yanberbot_0339.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_CR_doort_frame02369.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_yanberbot_0523.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_br_yanberbot_0296.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Red_BR_Duckbar_frame01112.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_br_zgxbot_00061.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_zgxbot_00073.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/b_cr_zgxbot_00098.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_br_yanberbot_0527.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_CR_doort_frame00607.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/d_br_yanberbot_2356.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_br_zgxbot_00052.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/Red_BR_Duckbar_frame01066.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/green_br_zgxbot_00002.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/blue_BR_doort_frame00557.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/red_BR_doort_frame01286.jpg',
#  '/Users/zhou/Desktop/duckietown/duckietown_raw_dataset/all_images/average/m_cr_zgxbot_